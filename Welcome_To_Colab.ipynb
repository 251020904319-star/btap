# %% [markdown]
# <a href="https://colab.research.google.com/github/251020904319-star/btap/blob/main/Welcome_To_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Welcome to Colab!

# %%
import math

s = input("Enter 3 real number (separated by space): ")
s = s.split()
a = float(s[0])
b = float(s[1])
c = float(s[2])
print(f"a = {a}, b= {b}, c = {c}")
delta = b**2 - 4*a*c
print("Delta =", delta)
if delta > 0:
    x1 = (-b + math.sqrt(delta)) / (2*a)
    x2 = (-b - math.sqrt(delta)) / (2*a)
    print("Phương trình có hai nghiệm phân biệt:")
    print("x1 =", x1)
    print("x2 =", x2)
elif delta == 0:
    x = -b / (2*a)
    print("Phương trình có nghiệm kép: x =", x)
else:
    print("Phương trình vô nghiệm trong tập số thực.")
# Out:
# Enter 3 real number (separated by space): 2 5 9
# a = 2.0, b= 5.0, c = 9.0
# Delta = -47.0
# Phương trình vô nghiệm trong tập số thực.

# %%
n = int(input("Enter a positive imteger::"))
print(n)
if n < 0:
    print("n phải là số nguyên dương!")
else:
    tong = 0
    for i in range(n + 1):
        tong += i
        print("Tổng từ 0 đến", n, "là:", tong)
# Out:
# Enter a positive imteger::15
# 15
# Tổng từ 0 đến 15 là: 0
# Tổng từ 0 đến 15 là: 1
# Tổng từ 0 đến 15 là: 3
# Tổng từ 0 đến 15 là: 6
# Tổng từ 0 đến 15 là: 10
# Tổng từ 0 đến 15 là: 15
# Tổng từ 0 đến 15 là: 21
# Tổng từ 0 đến 15 là: 28
# Tổng từ 0 đến 15 là: 36
# Tổng từ 0 đến 15 là: 45
# Tổng từ 0 đến 15 là: 55
# Tổng từ 0 đến 15 là: 66
# Tổng từ 0 đến 15 là: 78
# Tổng từ 0 đến 15 là: 91
# Tổng từ 0 đến 15 là: 105
# Tổng từ 0 đến 15 là: 120

# %%
n = int(input("Enter a positive integer:"))
print(n)
if n <= 0:
    print("n phải là số nguyên dương!")
else:
  i = 0
  while i < n:
        tong += i
        i += 2
        print("Tổng các số chẵn nhỏ hơn", n, "là:", tong)
# Out:
# Enter a positive integer:10
# 10
# Tổng các số chẵn nhỏ hơn 10 là: 120
# Tổng các số chẵn nhỏ hơn 10 là: 122
# Tổng các số chẵn nhỏ hơn 10 là: 126
# Tổng các số chẵn nhỏ hơn 10 là: 132
# Tổng các số chẵn nhỏ hơn 10 là: 140
